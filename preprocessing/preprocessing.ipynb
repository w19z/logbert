# %%
import pandas as pd
import datetime
import json

# %% [markdown]
# # log preprocessing

# %% [markdown]
# ## sshd

# %%
def transform_log(log_line, comp):
    prefix, json_part = log_line.split(": ", 1)
    log_data = json.loads(json_part)

    timestamp = log_data[0]
    timestamp = datetime.datetime.fromtimestamp(timestamp)

    log_message = log_data[1]["log"]
    log_message = log_message.split(comp, 1)[1]

    return f"{prefix.split('_')[0]} {timestamp}{log_message}"

# %%
with open('logs_out/wp1_sshd', 'r') as infile, open('logs_out/wp1', 'w') as outfile:
    for line in infile:
        transformed_line = transform_log(line, "wp1")
        outfile.write(transformed_line + '\n')

# %%
with open('logs_out/wp2_sshd', 'r') as infile, open('logs_out/wp2', 'w') as outfile:
    for line in infile:
        transformed_line = transform_log(line, "wp2")
        outfile.write(transformed_line + '\n')

# %%
with open('logs_out/sshd', 'r') as infile, open('logs_out/server', 'w') as outfile:
    for line in infile:
        transformed_line = transform_log(line, "server")
        outfile.write(transformed_line + '\n')

# %% [markdown]
# ## docker app

# %%
def transform_log(log_line):
    prefix, json_part = log_line.split(": ", 1)
    log_data = json.loads(json_part, strict=False)

    timestamp = log_data[0]
    timestamp = datetime.datetime.fromtimestamp(timestamp)

    log_message = log_data[1]["log"]

    return f"{prefix.split('.')[1]} {timestamp} {log_message}"

# %%
with open('logs_out/docker.app', 'r') as infile, open('logs_out/app', 'w') as outfile:
    for _, line in enumerate(infile):
        try:
            transformed_line = transform_log(line)
            outfile.write(transformed_line + '\n')
        except Exception as e:
            print(_, e)
            pass

# %% [markdown]
# ## docker db

# %%
def transform_log(log_line):
    prefix, json_part = log_line.split(": ", 1)
    log_data = json.loads(json_part, strict=False)

    timestamp = log_data[0]
    timestamp = datetime.datetime.fromtimestamp(timestamp)

    log_message = log_data[1]["log"]
    if log_message.find("LOG: ") != -1:
        log_message = log_message.split("LOG: ", 1)[1]

    return f"{prefix.split('.')[1]} {timestamp} {log_message}"

# %%
with open('logs_out/docker.db', 'r') as infile, open('logs_out/db', 'w') as outfile:
    for _, line in enumerate(infile):
        try:
            transformed_line = transform_log(line)
            outfile.write(transformed_line + '\n')
        except Exception as e:
            print(_, e)
            pass

# %% [markdown]
# ## docker jupyter

# %%
def transform_log(log_line):
    prefix, json_part = log_line.split(": ", 1)
    log_data = json.loads(json_part, strict=False)

    timestamp = log_data[0]
    timestamp = datetime.datetime.fromtimestamp(timestamp)

    log_message = log_data[1]["log"]

    return f"{prefix.split('.')[1]} {timestamp} {log_message}"

# %%
with open('logs_out/docker.jupyter', 'r') as infile, open('logs_out/jupyter', 'w') as outfile:
    for _, line in enumerate(infile):
        try:
            transformed_line = transform_log(line)
            outfile.write(transformed_line + '\n')
        except Exception as e:
            print(_, e)
            pass

# %% [markdown]
# # log parsing

# %%
! python log_parsing.py
# Out:
# Parsing file: ./db
# [Warning] Skip line: db 2024-05-10 22:00:08
#
# [Warning] Skip line: db 2024-05-10 22:00:10
#
# [Warning] Skip line: db 2024-05-10 22:00:10
#
# [Warning] Skip line: db 2024-05-10 22:15:05
#
# [Warning] Skip line: db 2024-05-10 22:30:08
#
# [Warning] Skip line: db 2024-05-10 22:30:09
# [Warning] Skip line: db 2024-05-11 18:30:12
#
# [Warning] Skip line: db 2024-05-11 18:30:12
#
# [Warning] Skip line: db 2024-05-11 18:45:03
#
# [Warning] Skip line: db 2024-05-11 19:00:04
#
# [Warning] Skip line: db 2024-05-11 19:00:07
#
# [Warning] Skip line: db 2024-05-11 19:00:07
#
# [Warning] Skip line: db 2024-05-11 19:15:04
#
# [Warning] Skip line: db 2024-05-11 19:30:05
#
# [Warning] Skip line: db 2024-05-11 19:30:08
#
# [Warning] Skip line: db 2024-05-11 19:30:08
#
# [Warning] Skip line: db 2024-05-11 19:45:03
#
# [Warning] Skip line: db 2024-05-11 20:00:05
#
# [Warning] Skip line: db 2024-05-11 20:00:06
#
# [Warning] Skip line: db 2024-05-11 20:00:06
#
# [Warning] Skip line: db 2024-05-11 20:15:07
#
# [Warning] Skip line: db 2024-05-11 20:30:04
#
# [Warning] Skip line: db 2024-05-11 20:30:08
#
# [Warning] Skip line: db 2024-05-11 20:30:08
#
# [Warning] Skip line: db 2024-05-11 20:45:03
#
# [Warning] Skip line: db 2024-05-11 21:00:06
#
# [Warning] Skip line: db 2024-05-11 21:00:08
#
# [Warning] Skip line: db 2024-05-11 21:15:05
#
# [Warning] Skip line: db 2024-05-11 21:30:06
#
# [Warning] Skip line: db 2024-05-11 21:30:06
#
# [Warning] Skip line: db 2024-05-11 21:30:08
#
# [Warning] Skip line: db 2024-05-11 21:45:08
#
# [Warning] Skip line: db 2024-05-11 22:00:07
#
# [Warning] Skip line: db 2024-05-11 22:00:16
#
# [Warning] Skip line: db 2024-05-11 22:00:16
#
# [Warning] Skip line: db 2024-05-11 22:15:04
#
# [Warning] Skip line: db 2024-05-11 22:30:06
#
# [Warning] Skip line: db 2024-05-11 22:30:07
#
# [Warning] Skip line: db 2024-05-11 22:30:07
#
# [Warning] Skip line: db 2024-05-11 22:45:03
#
# [Warning] Skip line: db 2024-05-11 23:00:04
#
# [Warning] Skip line: db 2024-05-11 23:00:07
#
# [Warning] Skip line: db 2024-05-11 23:00:07
#
# [Warning] Skip line: db 2024-05-11 23:15:07
#
# [Warning] Skip line: db 2024-05-11 23:30:06
#
# [Warning] Skip line: db 2024-05-11 23:30:12
#
# [Warning] Skip line: db 2024-05-11 23:30:12
#
# [Warning] Skip line: db 2024-05-11 23:45:04
#
# [Warning] Skip line: db 2024-05-12 00:00:04
#
# [Warning] Skip line: db 2024-05-12 00:00:09
#
# [Warning] Skip line: db 2024-05-12 00:00:09
#
# Total lines:  60539
# Processed 1.7% of log lines.
# Processed 3.3% of log lines.
# Processed 5.0% of log lines.
# Processed 6.6% of log lines.
# Processed 8.3% of log lines.
# Processed 9.9% of log lines.
# Processed 11.6% of log lines.
# Processed 13.2% of log lines.
# Processed 14.9% of log lines.
# Processed 16.5% of log lines.
# Processed 18.2% of log lines.
# Processed 19.8% of log lines.
# Processed 21.5% of log lines.
# Processed 23.1% of log lines.
# Processed 24.8% of log lines.
# Processed 26.4% of log lines.
# Processed 28.1% of log lines.
# Processed 29.7% of log lines.
# Processed 31.4% of log lines.
# Processed 33.0% of log lines.
# Processed 34.7% of log lines.
# Processed 36.3% of log lines.
# Processed 38.0% of log lines.
# Processed 39.6% of log lines.
# Processed 41.3% of log lines.
# Processed 42.9% of log lines.
# Processed 44.6% of log lines.
# Processed 46.3% of log lines.
# Processed 47.9% of log lines.
# Processed 49.6% of log lines.
# Processed 51.2% of log lines.
# Processed 52.9% of log lines.
# Processed 54.5% of log lines.
# Processed 56.2% of log lines.
# Processed 57.8% of log lines.
# Processed 59.5% of log lines.
# Processed 61.1% of log lines.
# Processed 62.8% of log lines.
# Processed 64.4% of log lines.
# Processed 66.1% of log lines.
# Processed 67.7% of log lines.
# Processed 69.4% of log lines.
# Processed 71.0% of log lines.
# Processed 72.7% of log lines.
# Processed 74.3% of log lines.
# Processed 76.0% of log lines.
# Processed 77.6% of log lines.
# Processed 79.3% of log lines.
# Processed 80.9% of log lines.
# Processed 82.6% of log lines.
# Processed 84.2% of log lines.
# Processed 85.9% of log lines.
# Processed 87.5% of log lines.
# Processed 89.2% of log lines.
# Processed 90.9% of log lines.
# Processed 92.5% of log lines.
# Processed 94.2% of log lines.
# Processed 95.8% of log lines.
# Processed 97.5% of log lines.
# Processed 99.1% of log lines.
# Processed 100.0% of log lines.
# Parsing done. [Time taken: 0:00:13.766101]
# Parsing file: ./app
# Total lines:  1546
# Processed 64.7% of log lines.
# Processed 100.0% of log lines.
# Parsing done. [Time taken: 0:00:00.281626]
# Parsing file: ./wp1
# Total lines:  48
# Processed 100.0% of log lines.
# Parsing done. [Time taken: 0:00:00.023998]
# Parsing file: ./wp2
# Total lines:  26
# Processed 100.0% of log lines.
# Parsing done. [Time taken: 0:00:00.012044]
# Parsing file: ./jupyter
# Total lines:  35478
# Processed 2.8% of log lines.
# Processed 5.6% of log lines.
# Processed 8.5% of log lines.
# Processed 11.3% of log lines.
# Processed 14.1% of log lines.
# Processed 16.9% of log lines.
# Processed 19.7% of log lines.
# Processed 22.5% of log lines.
# Processed 25.4% of log lines.
# Processed 28.2% of log lines.
# Processed 31.0% of log lines.
# Processed 33.8% of log lines.
# Processed 36.6% of log lines.
# Processed 39.5% of log lines.
# Processed 42.3% of log lines.
# Processed 45.1% of log lines.
# Processed 47.9% of log lines.
# Processed 50.7% of log lines.
# Processed 53.6% of log lines.
# Processed 56.4% of log lines.
# Processed 59.2% of log lines.
# Processed 62.0% of log lines.
# Processed 64.8% of log lines.
# Processed 67.6% of log lines.
# Processed 70.5% of log lines.
# Processed 73.3% of log lines.
# Processed 76.1% of log lines.
# Processed 78.9% of log lines.
# Processed 81.7% of log lines.
# Processed 84.6% of log lines.
# Processed 87.4% of log lines.
# Processed 90.2% of log lines.
# Processed 93.0% of log lines.
# Processed 95.8% of log lines.
# Processed 98.7% of log lines.
# Processed 100.0% of log lines.
# Parsing done. [Time taken: 0:00:08.906258]
# Parsing file: ./server
# Total lines:  120
# Processed 100.0% of log lines.
# Parsing done. [Time taken: 0:00:00.036573]

# %% [markdown]
# # combine logs

# %%
df1 = pd.read_csv('result/db_structured.csv')
df2 = pd.read_csv('result/jupyter_structured.csv')
df3 = pd.read_csv('result/app_structured.csv')
df4 = pd.read_csv('result/wp1_structured.csv')
df5 = pd.read_csv('result/wp2_structured.csv')
df6 = pd.read_csv('result/server_structured.csv')

# %%
df1['Datetime'] = pd.to_datetime(df1['Date'] + ' ' + df1['Time'])
df1.set_index('Datetime', inplace=True)
df2['Datetime'] = pd.to_datetime(df2['Date'] + ' ' + df2['Time'])
df2.set_index('Datetime', inplace=True)
df3['Datetime'] = pd.to_datetime(df3['Date'] + ' ' + df3['Time'])
df3.set_index('Datetime', inplace=True)
df4['Datetime'] = pd.to_datetime(df4['Date'] + ' ' + df4['Time'])
df4.set_index('Datetime', inplace=True)
df5['Datetime'] = pd.to_datetime(df5['Date'] + ' ' + df5['Time'])
df5.set_index('Datetime', inplace=True)
df6['Datetime'] = pd.to_datetime(df6['Date'] + ' ' + df6['Time'])
df6.set_index('Datetime', inplace=True)

# %%
combined_df = pd.concat([df1, df2, df3, df4, df5, df6])
combined_df.sort_index(inplace=True)

# %%
# fix line id
combined_df['LineId'] = [i for i in range(1, combined_df.shape[0] + 1)]

# %%
combined_df.drop(['Date', 'Time'], axis=1, inplace=True)

# %%
combined_df.to_csv('combined.csv')
combined_df.shape
# Out:
# (97757, 6)

# %%
# save templates
df1 = pd.read_csv('result/db_templates.csv')
df2 = pd.read_csv('result/jupyter_templates.csv')
df3 = pd.read_csv('result/app_templates.csv')
df4 = pd.read_csv('result/wp1_templates.csv')
df5 = pd.read_csv('result/wp2_templates.csv')
df6 = pd.read_csv('result/server_templates.csv')

templates_df = pd.concat([df1, df2, df3, df4, df5, df6])
templates_df.to_csv('templates.csv', index=False)

# %%
templates_df.head()
# Out:
#     EventId                                      EventTemplate  Occurrences
# 0  a5fc2aed      statement: UPDATE <*> SET <*> WHERE <*> = <*>        28217
# 1  c32030ca  statement: UPDATE dag SET is_active=false WHER...         9098
# 2  af812c53  statement: DELETE FROM import_error WHERE impo...         9123
# 3  c8ad4490  statement: UPDATE task_instance SET state='sch...         6192
# 4  004f521e  statement: UPDATE dag SET is_active=false WHER...           25

# %% [markdown]
# # labels

# %%
df = pd.read_csv('combined.csv')

# %%
df.sample()
# Out:
#                          Datetime  LineId Computer  \
# 83765  2024-05-11 20:03:21.000000   83766       db
#
#                                                  Content   EventId  \
# 83765  statement: UPDATE dag SET is_active=false WHER...  c32030ca
#
#                                            EventTemplate  \
# 83765  statement: UPDATE dag SET is_active=false WHER...
#
#                                            ParameterList
# 83765  ["'/opt/airflow/dags/prediction.py'", "('predi...

# %%
df['Label'] = 0

# %%
mask = df['Content'].str.contains('192.168.56.1', na=False)
filtered_df = df[mask]
filtered_df = filtered_df[filtered_df['Computer'] == 'app']

# anomaly 4
mask1 = filtered_df['Content'].str.contains('endpoint1', na=False)
# anomaly 2
mask2 = filtered_df['Content'].str.contains('endpoint3', na=False)
an4 = filtered_df[mask1].index
an2 = filtered_df[mask2].index

df.iloc[an4, -1] = 4
df.iloc[an2, -1] = 2

# %%
mask = df['Content'].str.contains('temp1', na=False)
filtered_df = df[mask]
# anomalies 1
an1 = filtered_df.index
df.iloc[an1, -1] = 1

# %%
df.to_csv('comb_structured.csv')

# %%
df['Label'].value_counts()
# Out:
# Label1
# 0    97703
# 4       27
# 1       17
# 2       10
# Name: count, dtype: int64
